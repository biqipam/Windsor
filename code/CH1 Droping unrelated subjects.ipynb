# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Zhou/Desktop/DoD修改2209/DoD_Grants_labeled处理后.csv')

# %%
lst = []
tar = ['orkshop','ymposium','onference']
for i in range(len(df)):
    for j in range(len(tar)):
        if(tar[j] in df['Project Title'][i]):
            lst.append(i)
print(len(lst))
print(lst)
# Out:
# 978
# ...

# %%
df1 = df.drop(lst)
print(len(df))
print(len(df1))
# Out:
# 18993
# 18050

# %%
df1.to_excel('C:/Users/Zhou/Desktop/DoD修改2209/DoD_删后.xlsx',encoding='UTF-8')
