# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Zhou/Desktop/DoD修改2209/DoD_删后.csv',index_col = 'Potential Period of Performance Start',parse_dates = ['Potential Period of Performance Start'])

# %%
df['num']=1

# %%
#df.head()

# %%
df_Quaterly = df['num'].resample('Q').count()

# %%
df_Quaterly
# Out:
# Potential Period of Performance Start
# 2010-09-30       1
# 2010-12-31       0
# 2011-03-31       0
# 2011-06-30       1
# 2011-09-30       1
# 2011-12-31       1
# 2012-03-31       2
# 2012-06-30       1
# 2012-09-30       1
# 2012-12-31       0
# 2013-03-31       0
# 2013-06-30       2
# 2013-09-30       2
# 2013-12-31       5
# 2014-03-31       3
# 2014-06-30       4
# 2014-09-30       8
# 2014-12-31      52
# 2015-03-31     290
# 2015-06-30     581
# 2015-09-30    1742
# 2015-12-31     370
# 2016-03-31     829
# 2016-06-30    1029
# 2016-09-30    1844
# 2016-12-31     242
# 2017-03-31     689
# 2017-06-30     666
# 2017-09-30    1580
# 2017-12-31     299
# 2018-03-31     496
# 2018-06-30     558
# 2018-09-30    1708
# 2018-12-31     137
# 2019-03-31     387
# 2019-06-30     582
# 2019-09-30    1172
# 2019-12-31     118
# 2020-03-31     253
# 2020-06-30     786
# 2020-09-30    1085
# 2020-12-31     107
# 2021-03-31     194
# 2021-06-30     213
# 2021-09-30       9
# ...

# %%
res1.to_csv('时间分布.csv')

# %%
df_Quaterly
# Out:
#                                        Unnamed: 0  Award Number  关键词-中文  \
# Potential Period of Performance Start
# 2010-09-30                                      1             1       1
# 2010-12-31                                      0             0       0
# 2011-03-31                                      0             0       0
# 2011-06-30                                      1             1       1
# 2011-09-30                                      1             1       1
# 2011-12-31                                      1             1       1
# 2012-03-31                                      2             2       2
# 2012-06-30                                      1             1       1
# 2012-09-30                                      1             1       1
# 2012-12-31                                      0             0       0
# 2013-03-31                                      0             0       0
# ...

# %% [markdown]
# #如何计算日期差
# ##这里不能把需要计算的日期值作为index

# %%
#df = pd.read_csv('C:/Users/Zhou/Desktop/DoD修改2209/DoD.csv',parse_dates = ['Potential Period of Performance Start','Potential Period of Performance End'])
#df[len]=df['Potential Period of Performance End']-df['Potential Period of Performance Start']
